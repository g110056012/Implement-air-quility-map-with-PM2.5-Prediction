# %%
import pandas as pd
import numpy as np
import os
import glob
Folder_Path = r'D:/download/test'          #處理資料的路徑 不包含csv名稱
os.chdir(Folder_Path)
file_list = os.listdir()
#csv_list = glob.glob('D:/download/資料處理 - 複製/')
#path_domestic = os.path.abspath(os.getcwd()) + 'D:/download/資料處理 - 複製/'
#non_domestic = glob.glob(os.path.join(file_list, "*.csv"))
df_domestic = pd.concat((pd.read_csv(f) for f in file_list))

# %%
#df_domestic=df_domestic.drop(columns=['Unnamed: 0'])
#df_domestic=df_domestic.dropna()
df_domestic=df_domestic.reset_index(drop=True)
df_domestic
# Out:
#            deviceId                 time  past_1_pm2.5  past_1_humi  \
# 0        6766983971  2020-01-01 08:02:54         13.64        85.26
# 1        6766983971  2020-01-01 09:02:55         15.76        85.40
# 2        6766983971  2020-01-01 10:02:55         17.34        82.29
# 3        6766983971  2020-01-01 11:02:55         19.46        79.03
# 4        6766983971  2020-01-01 12:02:55         18.93        76.92
# ...             ...                  ...           ...          ...
# 2884261  6880372986  2020-05-31 11:00:05          5.72        69.45
# 2884262  6880372986  2020-05-31 12:00:05          5.69        67.37
# 2884263  6880372986  2020-05-31 13:00:05          6.98        69.13
# 2884264  6880372986  2020-05-31 14:00:06          6.00        77.91
# 2884265  6880372986  2020-05-31 15:00:06          5.87        75.98
#
#          past_1_temp  past_2_pm2.5  past_2_humi  past_2_temp  past_3_pm2.5  \
# ...

# %%
kao=df_domestic[df_domestic['location']==0]
kao.to_csv("D:/download/完成/final0.csv",index=False)

# %%
df_domestic['past_1_pm2.5']=df_domestic['past_1_pm2.5'].astype(float)
df_domestic['past_1_humi']=df_domestic['past_1_humi'].astype(float)
df_domestic['past_1_temp']=df_domestic['past_1_temp'].astype(float)
df_domestic['past_2_pm2.5']=df_domestic['past_2_pm2.5'].astype(float)
df_domestic['past_2_humi']=df_domestic['past_2_humi'].astype(float)
df_domestic['past_2_temp']=df_domestic['past_2_temp'].astype(float)
df_domestic['past_3_pm2.5']=df_domestic['past_3_pm2.5'].astype(float)
df_domestic['past_3_temp']=df_domestic['past_3_temp'].astype(float)
df_domestic['past_3_humi']=df_domestic['past_3_humi'].astype(float)
df_domestic['past_4_pm2.5']=df_domestic['past_4_pm2.5'].astype(float)
df_domestic['past_4_temp']=df_domestic['past_4_temp'].astype(float)
df_domestic['past_4_humi']=df_domestic['past_4_humi'].astype(float)
df_domestic['past_5_pm2.5']=df_domestic['past_5_pm2.5'].astype(float)
df_domestic['past_5_temp']=df_domestic['past_5_temp'].astype(float)
df_domestic['past_5_humi']=df_domestic['past_5_humi'].astype(float)
df_domestic['past_6_pm2.5']=df_domestic['past_6_pm2.5'].astype(float)
df_domestic['past_6_temp']=df_domestic['past_6_temp'].astype(float)
df_domestic['past_6_humi']=df_domestic['past_6_humi'].astype(float)
df_domestic['past_7_pm2.5']=df_domestic['past_7_pm2.5'].astype(float)
df_domestic['past_7_humi']=df_domestic['past_7_humi'].astype(float)
df_domestic['past_7_temp']=df_domestic['past_7_temp'].astype(float)
df_domestic['past_8_pm2.5']=df_domestic['past_8_pm2.5'].astype(float)
df_domestic['past_8_humi']=df_domestic['past_8_humi'].astype(float)
df_domestic['past_8_temp']=df_domestic['past_8_temp'].astype(float)

# %%
kao=df_domestic[df_domestic['location']==5]
kao.to_csv("D:/download/完成/final5.csv",index=False)

# %%
kao=df_domestic[df_domestic['location']==4]
kao.to_csv("D:/download/完成/final4.csv",index=False)

# %%
kao=df_domestic[df_domestic['location']==3]
kao.to_csv("D:/download/完成/final3.csv",index=False)

# %%
kao=df_domestic[df_domestic['location']==2]
kao.to_csv("D:/download/完成/final2.csv",index=False)

# %%
kao=df_domestic[df_domestic['location']==1]
kao.to_csv("D:/download/完成/final1.csv",index=False)
